# %%
import pandas as pd
import requests

# %%
requests.get('https://covid-19.dataflowkit.com/v1/usa')
# Out:
# <Response [200]>

# %%
response=requests.get('https://covid-19.dataflowkit.com/v1/usa')

# %%
response.json()
# Out:
# {'Active Cases_text': '',
#  'Country_text': 'USA',
#  'Last Update': '2023-12-28 22:09',
#  'New Cases_text': '',
#  'New Deaths_text': '',
#  'Total Cases_text': '110,057,289',
#  'Total Deaths_text': '1,190,019',
#  'Total Recovered_text': '107,829,742'}

# %%
df=pd.DataFrame(response.json(),index=pd.DataFrame(['Country_text','Total Cases_text','Total Deaths_text','Total Recovered_text']))
df
# Out:
#                         Active Cases_text Country_text       Last Update  \
# (Country_text,)                                    USA  2023-12-28 22:09
# (Total Cases_text,)                                USA  2023-12-28 22:09
# (Total Deaths_text,)                               USA  2023-12-28 22:09
# (Total Recovered_text,)                            USA  2023-12-28 22:09
#
#                         New Cases_text New Deaths_text Total Cases_text  \
# (Country_text,)                                             110,057,289
# (Total Cases_text,)                                         110,057,289
# (Total Deaths_text,)                                        110,057,289
# (Total Recovered_text,)                                     110,057,289
#
#                         Total Deaths_text Total Recovered_text
# (Country_text,)                 1,190,019          107,829,742
# (Total Cases_text,)             1,190,019          107,829,742
# ...

# %%
df.to_csv('uscovid.csv')

# %%
df=pd.read_csv('uscovid.csv')
df
# Out:
#                   Unnamed: 0  Active Cases_text Country_text  \
# 0          ('Country_text',)                NaN          USA
# 1      ('Total Cases_text',)                NaN          USA
# 2     ('Total Deaths_text',)                NaN          USA
# 3  ('Total Recovered_text',)                NaN          USA
#
#         Last Update  New Cases_text  New Deaths_text Total Cases_text  \
# 0  2023-12-28 22:09             NaN              NaN      110,057,289
# 1  2023-12-28 22:09             NaN              NaN      110,057,289
# 2  2023-12-28 22:09             NaN              NaN      110,057,289
# 3  2023-12-28 22:09             NaN              NaN      110,057,289
#
#   Total Deaths_text Total Recovered_text
# 0         1,190,019          107,829,742
# 1         1,190,019          107,829,742
# 2         1,190,019          107,829,742
# 3         1,190,019          107,829,742
